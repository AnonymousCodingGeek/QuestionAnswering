# %%
# Make sure you have a GPU running
# !nvidia-smi
# Out:
# Wed Jun 29 06:12:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install farm-haystack[all]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: farm-haystack[all] in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: quantulum3 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.7.10)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (4.11.4)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.8.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.6.3)
# Requirement already satisfied: mmh3 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.0.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (8.13.0)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.2.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.3.5.1)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.0.9)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.3.5)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.0.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (4.64.0)
# Requirement already satisfied: tika in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.24)
# Requirement already satisfied: posthog in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.4.9)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.4.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.0.2)
# Requirement already satisfied: azure-ai-formrecognizer==3.2.0b2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.2.0b2)
# Requirement already satisfied: mlflow in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.27.0)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.2.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.8.11)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.7)
# Requirement already satisfied: elastic-apm in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (6.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.23.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (4.3.3)
# Requirement already satisfied: elasticsearch<=7.10,>=7.7 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (7.9.1)
# Requirement already satisfied: torch<1.12,>1.9 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.11.0+cu113)
# Requirement already satisfied: azure-core<1.23 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.22.1)
# Requirement already satisfied: transformers==4.19.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (4.19.2)
# Requirement already satisfied: msrest>=0.6.21 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack[all]) (0.6.21)
# Requirement already satisfied: azure-common~=1.1 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack[all]) (1.1.28)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack[all]) (1.15.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.19.2->farm-haystack[all]) (5.4.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.19.2->farm-haystack[all]) (0.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.19.2->farm-haystack[all]) (3.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.19.2->farm-haystack[all]) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.19.2->farm-haystack[all]) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.19.2->farm-haystack[all]) (0.8.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.19.2->farm-haystack[all]) (2022.6.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack[all]) (1.25.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack[all]) (2022.6.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.19.2->farm-haystack[all]) (3.10.0.2)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack[all]) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack[all]) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.19.2->farm-haystack[all]) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack[all]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack[all]) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack[all]) (3.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack[all]) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack[all]) (1.1.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=2.2.0->farm-haystack[all]) (0.1.96)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=2.2.0->farm-haystack[all]) (0.12.0+cu113)
# Requirement already satisfied: pdf2image==1.14.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.14.0)
# Requirement already satisfied: pytesseract==0.3.7 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.3.7)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (7.1.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.3.7)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.4.27)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (4.6.3)
# Requirement already satisfied: aiorwlock<2,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.3.0)
# Requirement already satisfied: ray<2,>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.13.0)
# Requirement already satisfied: beir in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.0.0)
# Requirement already satisfied: mkdocs in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.3.0)
# Requirement already satisfied: pylint in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.14.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (5.4.8)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.1.9)
# Requirement already satisfied: requests-cache in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.9.4)
# Requirement already satisfied: responses in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.21.0)
# Requirement already satisfied: mypy in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.961)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.0.5)
# Requirement already satisfied: tox in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.12.1)
# Requirement already satisfied: jupytercontrib in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.0.7)
# Requirement already satisfied: pydoc-markdown==4.5.1 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (4.5.1)
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.7.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.6.4)
# Requirement already satisfied: black[jupyter] in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (22.6.0)
# Requirement already satisfied: onnxruntime-tools in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.7.0)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.11.1)
# Requirement already satisfied: webdriver-manager in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.7.1)
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.141.0)
# Requirement already satisfied: toml<0.11.0,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from pydoc-markdown==4.5.1->farm-haystack[all]) (0.10.2)
# Requirement already satisfied: docspec<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pydoc-markdown==4.5.1->farm-haystack[all]) (1.3.0)
# Requirement already satisfied: databind<2.0.0,>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pydoc-markdown==4.5.1->farm-haystack[all]) (1.5.2)
# Requirement already satisfied: docspec-python<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pydoc-markdown==4.5.1->farm-haystack[all]) (1.2.0)
# Requirement already satisfied: nr.fs<2.0.0,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from pydoc-markdown==4.5.1->farm-haystack[all]) (1.6.3)
# Requirement already satisfied: nr.stream<0.2.0,>=0.1.2 in /usr/local/lib/python3.7/dist-packages (from pydoc-markdown==4.5.1->farm-haystack[all]) (0.1.2)
# Requirement already satisfied: click<9.0,>=7.1 in /usr/local/lib/python3.7/dist-packages (from pydoc-markdown==4.5.1->farm-haystack[all]) (8.0.4)
# Requirement already satisfied: docstring-parser<0.12,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pydoc-markdown==4.5.1->farm-haystack[all]) (0.11)
# Requirement already satisfied: databind.json<2.0.0,>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from databind<2.0.0,>=1.5.0->pydoc-markdown==4.5.1->farm-haystack[all]) (1.5.2)
# Requirement already satisfied: databind.core<2.0.0,>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from databind<2.0.0,>=1.5.0->pydoc-markdown==4.5.1->farm-haystack[all]) (1.5.2)
# Requirement already satisfied: nr.util<1.0.0,>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from databind.core<2.0.0,>=1.5.2->databind<2.0.0,>=1.5.0->pydoc-markdown==4.5.1->farm-haystack[all]) (0.8.12)
# Requirement already satisfied: Deprecated<2.0.0,>=1.2.12 in /usr/local/lib/python3.7/dist-packages (from databind.core<2.0.0,>=1.5.2->databind<2.0.0,>=1.5.0->pydoc-markdown==4.5.1->farm-haystack[all]) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from Deprecated<2.0.0,>=1.2.12->databind.core<2.0.0,>=1.5.2->databind<2.0.0,>=1.5.0->pydoc-markdown==4.5.1->farm-haystack[all]) (1.14.1)
# Requirement already satisfied: nr.pylang.utils<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from nr.stream<0.2.0,>=0.1.2->pydoc-markdown==4.5.1->farm-haystack[all]) (0.1.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray<2,>=1.9.1->farm-haystack[all]) (21.4.0)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray<2,>=1.9.1->farm-haystack[all]) (1.37.1)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray<2,>=1.9.1->farm-haystack[all]) (3.17.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray<2,>=1.9.1->farm-haystack[all]) (1.0.4)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.7/dist-packages (from ray<2,>=1.9.1->farm-haystack[all]) (1.2.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.7/dist-packages (from ray<2,>=1.9.1->farm-haystack[all]) (1.3.0)
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.7/dist-packages (from ray<2,>=1.9.1->farm-haystack[all]) (20.15.1)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.7/dist-packages (from beir->farm-haystack[all]) (1.7.2)
# Requirement already satisfied: pytrec-eval in /usr/local/lib/python3.7/dist-packages (from beir->farm-haystack[all]) (0.5)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from black[jupyter]->farm-haystack[all]) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.7/dist-packages (from black[jupyter]->farm-haystack[all]) (0.4.3)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from black[jupyter]->farm-haystack[all]) (0.9.0)
# Requirement already satisfied: typed-ast>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from black[jupyter]->farm-haystack[all]) (1.5.4)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.7/dist-packages (from black[jupyter]->farm-haystack[all]) (2.5.2)
# Requirement already satisfied: ipython>=7.8.0 in /usr/local/lib/python3.7/dist-packages (from black[jupyter]->farm-haystack[all]) (7.34.0)
# Requirement already satisfied: tokenize-rt>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from black[jupyter]->farm-haystack[all]) (4.2.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (2.6.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (3.0.30)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (0.18.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.8.0->black[jupyter]->farm-haystack[all]) (0.2.5)
# Requirement already satisfied: weaviate-client==3.3.3 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (3.3.3)
# Requirement already satisfied: SPARQLWrapper in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.0.0)
# Requirement already satisfied: validators<0.19.0,>=0.18.2 in /usr/local/lib/python3.7/dist-packages (from weaviate-client==3.3.3->farm-haystack[all]) (0.18.2)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.9.3)
# Requirement already satisfied: sqlalchemy<2,>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (1.4.37)
# Requirement already satisfied: sqlalchemy-utils in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (0.38.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy<2,>=1.4.2->farm-haystack[all]) (1.1.2)
# Requirement already satisfied: pymilvus<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.0.2)
# Requirement already satisfied: ujson<=5.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pymilvus<3,>=2.0.0->farm-haystack[all]) (5.1.0)
# Requirement already satisfied: grpcio-tools==1.37.1 in /usr/local/lib/python3.7/dist-packages (from pymilvus<3,>=2.0.0->farm-haystack[all]) (1.37.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->farm-haystack[all]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->farm-haystack[all]) (2022.1)
# Requirement already satisfied: pinecone-client in /usr/local/lib/python3.7/dist-packages (from farm-haystack[all]) (2.0.11)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->farm-haystack[all]) (3.8.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->farm-haystack[all]) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->farm-haystack[all]) (5.7.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from jupytercontrib->farm-haystack[all]) (5.6.1)
# Requirement already satisfied: Jinja2>=2.10.2 in /usr/local/lib/python3.7/dist-packages (from mkdocs->farm-haystack[all]) (3.1.2)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /usr/local/lib/python3.7/dist-packages (from mkdocs->farm-haystack[all]) (0.1)
# Requirement already satisfied: mergedeep>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from mkdocs->farm-haystack[all]) (1.3.4)
# Requirement already satisfied: ghp-import>=1.0 in /usr/local/lib/python3.7/dist-packages (from mkdocs->farm-haystack[all]) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10.2->mkdocs->farm-haystack[all]) (2.0.1)
# Requirement already satisfied: docker>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (5.0.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (1.3.0)
# Requirement already satisfied: prometheus-flask-exporter in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (0.20.2)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (2.1.2)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (1.8.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (0.4)
# Requirement already satisfied: querystring-parser in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (1.2.4)
# Requirement already satisfied: gitpython>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (3.1.27)
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (0.4.2)
# Requirement already satisfied: databricks-cli>=0.8.7 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (0.17.0)
# Requirement already satisfied: gunicorn in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack[all]) (20.1.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.7->mlflow->farm-haystack[all]) (2.4.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.7->mlflow->farm-haystack[all]) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from docker>=4.0.0->mlflow->farm-haystack[all]) (1.3.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython>=2.1.0->mlflow->farm-haystack[all]) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->farm-haystack[all]) (5.0.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->mlflow->farm-haystack[all]) (1.2.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow->farm-haystack[all]) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow->farm-haystack[all]) (2.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupytercontrib->farm-haystack[all]) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupytercontrib->farm-haystack[all]) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupytercontrib->farm-haystack[all]) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupytercontrib->farm-haystack[all]) (0.6.0)
# Requirement already satisfied: nbformat>=4.4 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupytercontrib->farm-haystack[all]) (5.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupytercontrib->farm-haystack[all]) (0.7.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupytercontrib->farm-haystack[all]) (4.10.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.4->nbconvert->jupytercontrib->farm-haystack[all]) (2.15.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->jupytercontrib->farm-haystack[all]) (0.5.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime->farm-haystack[all]) (2.0)
# Requirement already satisfied: py3nvml in /usr/local/lib/python3.7/dist-packages (from onnxruntime-tools->farm-haystack[all]) (0.2.7)
# Requirement already satisfied: onnx in /usr/local/lib/python3.7/dist-packages (from onnxruntime-tools->farm-haystack[all]) (1.12.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.7/dist-packages (from onnxruntime-tools->farm-haystack[all]) (8.0.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.7/dist-packages (from onnxruntime-tools->farm-haystack[all]) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.7/dist-packages (from coloredlogs->onnxruntime-tools->farm-haystack[all]) (10.0)
# Requirement already satisfied: loguru>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from pinecone-client->farm-haystack[all]) (0.6.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pinecone-client->farm-haystack[all]) (2.2.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.7/dist-packages (from posthog->farm-haystack[all]) (1.6)
# Requirement already satisfied: backoff<2.0.0,>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from posthog->farm-haystack[all]) (1.11.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from prometheus-flask-exporter->mlflow->farm-haystack[all]) (0.14.1)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (from py3nvml->onnxruntime-tools->farm-haystack[all]) (0.13.0)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /usr/local/lib/python3.7/dist-packages (from pylint->farm-haystack[all]) (0.7.0)
# Requirement already satisfied: astroid<=2.12.0-dev0,>=2.11.6 in /usr/local/lib/python3.7/dist-packages (from pylint->farm-haystack[all]) (2.11.6)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from pylint->farm-haystack[all]) (0.11.0)
# Requirement already satisfied: isort<6,>=4.2.5 in /usr/local/lib/python3.7/dist-packages (from pylint->farm-haystack[all]) (5.10.1)
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from astroid<=2.12.0-dev0,>=2.11.6->pylint->farm-haystack[all]) (1.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->farm-haystack[all]) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->farm-haystack[all]) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->farm-haystack[all]) (0.7.1)
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx->farm-haystack[all]) (4.2.6)
# Requirement already satisfied: num2words in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack[all]) (0.5.10)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack[all]) (2.1.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words->quantulum3->farm-haystack[all]) (0.6.2)
# Requirement already satisfied: jarowinkler<1.1.0,>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from rapidfuzz->farm-haystack[all]) (1.0.4)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache->farm-haystack[all]) (1.4.4)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache->farm-haystack[all]) (1.4.3)
# Requirement already satisfied: cattrs<2.0,>=1.8 in /usr/local/lib/python3.7/dist-packages (from requests-cache->farm-haystack[all]) (1.10.0)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.7/dist-packages (from SPARQLWrapper->farm-haystack[all]) (6.1.1)
# Requirement already satisfied: distlib<1,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from virtualenv->ray<2,>=1.9.1->farm-haystack[all]) (0.3.4)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (from webdriver-manager->farm-haystack[all]) (0.20.0)

# %%
"""
You might get a warning on executing the above cell for the first time due to some dependency issues
In that case please restart the runtime and run the above cell again otherwise the cells below won't get executed
"""

# %%
from haystack.utils import convert_files_to_docs, fetch_archive_from_http, clean_wiki_text
from haystack.nodes import Seq2SeqGenerator
# Out:
# INFO - haystack.modeling.model.optimization -  apex not found, won't use it. See https://nvidia.github.io/apex/
# ERROR - root -  Failed to import 'magic' (from 'python-magic' and 'python-magic-bin' on Windows). FileTypeClassifier will not perform mimetype detection on extensionless files. Please make sure the necessary OS libraries are installed if you need this functionality.

# %%
from haystack.document_stores import FAISSDocumentStore

document_store = FAISSDocumentStore(embedding_dim=128, faiss_index_factory_str="Flat")
# Out:
# INFO - haystack.telemetry -  Haystack sends anonymous usage data to understand the actual usage and steer dev efforts towards features that are most meaningful to users. You can opt-out at anytime by calling disable_telemetry() or by manually setting the environment variable HAYSTACK_TELEMETRY_ENABLED as described for different operating systems on the documentation page. More information at https://haystack.deepset.ai/guides/telemetry

# %%
# !wget --no-check-certificate https://dl.xpdfreader.com/xpdf-tools-linux-4.04.tar.gz
# !tar -xvf xpdf-tools-linux-4.04.tar.gz && sudo cp xpdf-tools-linux-4.04/bin64/pdftotext /usr/local/bin
# Out:
# --2022-06-29 06:15:12--  https://dl.xpdfreader.com/xpdf-tools-linux-4.04.tar.gz
# Resolving dl.xpdfreader.com (dl.xpdfreader.com)... 45.79.72.155
# Connecting to dl.xpdfreader.com (dl.xpdfreader.com)|45.79.72.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23687259 (23M) [application/x-gzip]
# Saving to: ‘xpdf-tools-linux-4.04.tar.gz’
#
# xpdf-tools-linux-4. 100%[===================>]  22.59M  21.8MB/s    in 1.0s
#
# 2022-06-29 06:15:14 (21.8 MB/s) - ‘xpdf-tools-linux-4.04.tar.gz’ saved [23687259/23687259]
#
# xpdf-tools-linux-4.04/
# xpdf-tools-linux-4.04/CHANGES
# xpdf-tools-linux-4.04/COPYING3
# xpdf-tools-linux-4.04/INSTALL
# xpdf-tools-linux-4.04/ANNOUNCE
# xpdf-tools-linux-4.04/bin64/
# xpdf-tools-linux-4.04/bin64/pdftopng
# xpdf-tools-linux-4.04/bin64/pdftohtml
# xpdf-tools-linux-4.04/bin64/pdfinfo
# xpdf-tools-linux-4.04/bin64/pdffonts
# xpdf-tools-linux-4.04/bin64/pdfimages
# xpdf-tools-linux-4.04/bin64/pdftotext
# xpdf-tools-linux-4.04/bin64/pdftoppm
# xpdf-tools-linux-4.04/bin64/pdftops
# xpdf-tools-linux-4.04/bin64/pdfdetach
# xpdf-tools-linux-4.04/README
# xpdf-tools-linux-4.04/COPYING
# xpdf-tools-linux-4.04/doc/
# xpdf-tools-linux-4.04/doc/pdftohtml.1
# xpdf-tools-linux-4.04/doc/pdftops.1
# xpdf-tools-linux-4.04/doc/pdfimages.1
# xpdf-tools-linux-4.04/doc/sample-xpdfrc
# xpdf-tools-linux-4.04/doc/pdffonts.1
# xpdf-tools-linux-4.04/doc/pdfdetach.1
# xpdf-tools-linux-4.04/doc/pdftoppm.1
# xpdf-tools-linux-4.04/doc/pdftotext.1
# xpdf-tools-linux-4.04/doc/pdftopng.1
# xpdf-tools-linux-4.04/doc/xpdfrc.5
# xpdf-tools-linux-4.04/doc/pdfinfo.1
# xpdf-tools-linux-4.04/bin32/
# xpdf-tools-linux-4.04/bin32/pdftopng
# xpdf-tools-linux-4.04/bin32/pdftohtml
# xpdf-tools-linux-4.04/bin32/pdfinfo
# xpdf-tools-linux-4.04/bin32/pdffonts
# xpdf-tools-linux-4.04/bin32/pdfimages
# xpdf-tools-linux-4.04/bin32/pdftotext
# xpdf-tools-linux-4.04/bin32/pdftoppm
# xpdf-tools-linux-4.04/bin32/pdftops
# xpdf-tools-linux-4.04/bin32/pdfdetach

# %%
doc_dir="sample_data/files"

"""
Add the files to be used for fine-tuning to a folder in your colab notebook
For example here I created a folder named files in the default sample-data folder of my colab notebook
and I added the required files to this folder
"""
# Out:
# '\nAdd the files to be used for fine-tuning to a folder in your colab notebook\nFor example here I created a folder named files in the default sample-data folder of my colab notebook\nand I added the required files to this folder\n'

# %%
from haystack.utils.preprocessing import convert_files_to_docs
docs = convert_files_to_docs(dir_path=doc_dir, clean_func=clean_wiki_text, split_paragraphs=True)
# Out:
# INFO - haystack.utils.preprocessing -  Converting sample_data/files/BERT Research Paper_00001.txt

# %%
document_store.write_documents(docs)
# Out:
# Writing Documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from haystack.nodes import DensePassageRetriever

retriever = DensePassageRetriever(
    document_store=document_store,
    query_embedding_model="vblagoje/dpr-question_encoder-single-lfqa-wiki",
    passage_embedding_model="vblagoje/dpr-ctx_encoder-single-lfqa-wiki",
)

document_store.update_embeddings(retriever)
# Out:
# INFO - haystack.modeling.utils -  Using devices: CUDA:0
# INFO - haystack.modeling.utils -  Number of GPUs: 1
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/495 [00:00<?, ?B/s]
# INFO - haystack.modeling.model.language_model -  LOADING MODEL
# INFO - haystack.modeling.model.language_model -  =============
# INFO - haystack.modeling.model.language_model -  Could not find vblagoje/dpr-question_encoder-single-lfqa-wiki locally.
# INFO - haystack.modeling.model.language_model -  Looking on Transformers Model Hub (in local cache and online)...
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# INFO - haystack.modeling.model.language_model -  Loaded vblagoje/dpr-question_encoder-single-lfqa-wiki
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/494 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizerFast'.
# INFO - haystack.modeling.model.language_model -  LOADING MODEL
# INFO - haystack.modeling.model.language_model -  =============
# INFO - haystack.modeling.model.language_model -  Could not find vblagoje/dpr-ctx_encoder-single-lfqa-wiki locally.
# INFO - haystack.modeling.model.language_model -  Looking on Transformers Model Hub (in local cache and online)...
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# INFO - haystack.modeling.model.language_model -  Loaded vblagoje/dpr-ctx_encoder-single-lfqa-wiki
# INFO - haystack.document_stores.faiss -  Updating embeddings for 1 docs...
# Updating Embedding:   0%|          | 0/1 [00:00<?, ? docs/s]

# %%
generator = Seq2SeqGenerator(model_name_or_path="vblagoje/bart_lfqa")
# Out:
# INFO - haystack.modeling.utils -  Using devices: CUDA
# INFO - haystack.modeling.utils -  Number of GPUs: 1
# Downloading:   0%|          | 0.00/27.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.51G [00:00<?, ?B/s]

# %%
from haystack.pipelines import GenerativeQAPipeline
       
pipe = GenerativeQAPipeline(generator, retriever)

# %%
res=pipe.run(query="Who is Virat Kohli?", params={"Retriever": {"top_k": 3}})

# %%
answer=res['answers'][0].answer

# %%
answer
